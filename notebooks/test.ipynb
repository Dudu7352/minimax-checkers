# %%
from checkers import GameState, GameNode, MiniMaxGameTree, new_board
from math import inf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from checkers import GameState, GameNode, MiniMaxGameTree, new_board
#       2 from math import inf
#
# ImportError: cannot import name 'MiniMaxGameTree' from 'checkers' (/Users/krystian/Documents/Projects/Golem Checkers/minimax-checkers/src/checkers/__init__.py)

# %%
bot1 = MiniMaxGameTree(GameNode(GameState(new_board()), 0), 6)  # b player
bot2 = MiniMaxGameTree(GameNode(GameState(new_board()), 0), 3)  # r player
child_node_1 = bot1.minimax_move(True, None)
print(str(child_node_1.state))

while True:
    child_node_2 = bot2.minimax_move(False, child_node_1)
    if not child_node_2:
        break
    print(str(child_node_2.state))
    child_node_1 = bot1.minimax_move(False, child_node_2)
    
    if not child_node_1:
        break
    print(str(child_node_1.state))
    
    if abs(child_node_2.state.score) == inf or abs(child_node_1.state.score) == inf:
        break
    
print("game over")
# Out:
# +-curr:r-+
# | b b b b|
# |b b b b |
# | b b b  |
# |      b |
# |        |
# |r r r r |
# | r r r r|
# |r r r r |
# +-| 0.0|-+
# +-curr:b-+
# | b b b b|
# |b b b b |
# | b b b  |
# |      b |
# |       r|
# |r r r   |
# | r r r r|
# |r r r r |
# +-| 0.0|-+
# +-curr:r-+
# | b b b b|
# |b b b b |
# | b b b  |
# |        |
# |     b r|
# |r r r   |
# | r r r r|
# |r r r r |
# +-| 0.0|-+
# +-curr:b-+
# | b b b b|
# |b b b b |
# | b b b  |
# |      r |
# |       r|
# |r r     |
# | r r r r|
# |r r r r |
# +-| 1.0|-+
# +-curr:r-+
# | b b b b|
# |b b b b |
# | b b    |
# |    b r |
# |       r|
# |r r     |
# | r r r r|
# |r r r r |
# +-| 1.0|-+
# +-curr:b-+
# | b b b b|
# |b b b b |
# | b b    |
# |    b r |
# |       r|
# |r r   r |
# | r r r  |
# |r r r r |
# +-| 1.0|-+
# +-curr:r-+
# | b b b b|
# |b b b b |
# | b b    |
# |      r |
# |     b r|
# |r r   r |
# | r r r  |
# |r r r r |
# +-| 1.0|-+
# +-curr:b-+
# | b b b b|
# |b b b b |
# | b b    |
# |    r r |
# |       r|
# |r r     |
# | r r r  |
# |r r r r |
# +-| 2.0|-+
# +-curr:r-+
# | b b b b|
# |b b b b |
# | b     b|
# |        |
# |       r|
# |r r     |
# | r r r  |
# |r r r r |
# +-| 0.0|-+
# +-curr:b-+
# | b b b b|
# |b b b b |
# | b     b|
# |        |
# |       r|
# |r r     |
# | r r r r|
# |r r r   |
# +-| 0.0|-+
# +-curr:r-+
# | b b b b|
# |b b b b |
# | b      |
# |      b |
# |       r|
# |r r     |
# | r r r r|
# |r r r   |
# +-| 0.0|-+
# +-curr:b-+
# | b b b b|
# |b b b b |
# | b   r  |
# |        |
# |        |
# |r r     |
# | r r r r|
# |r r r   |
# +-| 1.0|-+
# +-curr:r-+
# | b b b b|
# |b b b   |
# | b      |
# |    b   |
# |        |
# |r r     |
# | r r r r|
# |r r r   |
# +-| 0.0|-+
# +-curr:b-+
# | b b b b|
# |b b b   |
# | b      |
# |    b   |
# |        |
# |r r   r |
# | r r r  |
# |r r r   |
# +-| 0.0|-+
# +-curr:r-+
# | b b b b|
# |b b b   |
# | b      |
# |        |
# |     b  |
# |r r   r |
# | r r r  |
# |r r r   |
# +-| 0.0|-+
# +-curr:b-+
# | b b b b|
# |b b b   |
# | b      |
# |    r   |
# |        |
# |r r     |
# | r r r  |
# |r r r   |
# +-| 1.0|-+
# +-curr:r-+
# | b b b b|
# |b b b   |
# |        |
# |  b r   |
# |        |
# |r r     |
# | r r r  |
# |r r r   |
# +-| 1.0|-+
# +-curr:b-+
# | b b b b|
# |b b b   |
# |        |
# |  b r   |
# |        |
# |r r   r |
# | r r    |
# |r r r   |
# +-| 1.0|-+
# +-curr:r-+
# | b b b b|
# |b b b   |
# |        |
# |    r   |
# | b      |
# |r r   r |
# | r r    |
# |r r r   |
# +-| 1.0|-+
# +-curr:b-+
# | b b b b|
# |b b b   |
# |        |
# |r   r   |
# |        |
# |r     r |
# | r r    |
# |r r r   |
# +-| 2.0|-+
# +-curr:r-+
# | b b b b|
# |b   b   |
# | b      |
# |r   r   |
# |        |
# |r     r |
# | r r    |
# |r r r   |
# +-| 2.0|-+
# +-curr:b-+
# | b b b b|
# |b r b   |
# |        |
# |    r   |
# |        |
# |r     r |
# | r r    |
# |r r r   |
# +-| 3.0|-+
# +-curr:r-+
# |   b b b|
# |b   b   |
# |        |
# |        |
# |        |
# |r       |
# | r r   b|
# |r r r   |
# +-| 0.0|-+
# +-curr:b-+
# |   b b b|
# |b   b   |
# |        |
# |        |
# |        |
# |r       |
# | r r r b|
# |r r     |
# +-| 0.0|-+
# +-curr:r-+
# |   b b b|
# |b       |
# |     b  |
# |        |
# |        |
# |r       |
# | r r r b|
# |r r     |
# +-| 0.0|-+
# +-curr:b-+
# |   b b b|
# |b       |
# |     b  |
# |        |
# |        |
# |r     r |
# | r r   b|
# |r r     |
# +-| 0.0|-+
# +-curr:r-+
# |   b b b|
# |b       |
# |     b  |
# |        |
# |        |
# |r     r |
# | r r    |
# |r r   B |
# +-|-0.5|-+
# +-curr:b-+
# |   b b b|
# |b       |
# |     b  |
# |        |
# |        |
# |r   r r |
# | r      |
# |r r   B |
# +-|-0.5|-+
# +-curr:r-+
# |   b b b|
# |b       |
# |     b  |
# |        |
# |        |
# |r   r r |
# | r     B|
# |r r     |
# +-|-0.5|-+
# +-curr:b-+
# |   b b b|
# |b       |
# |     b  |
# |        |
# |        |
# |r   r r |
# | r r   B|
# |r       |
# +-|-0.5|-+
# +-curr:r-+
# |   b b b|
# |b       |
# |     b  |
# |        |
# |     B  |
# |r   r   |
# | r r    |
# |r       |
# +-|-1.5|-+
# +-curr:b-+
# |   b b b|
# |b   r   |
# |        |
# |        |
# |        |
# |r       |
# | r r    |
# |r       |
# +-| 1.0|-+
# +-curr:r-+
# |   b   b|
# |b       |
# |   b    |
# |        |
# |        |
# |r       |
# | r r    |
# |r       |
# +-| 0.0|-+
# +-curr:b-+
# |   b   b|
# |b       |
# |   b    |
# |        |
# |        |
# |r   r   |
# | r      |
# |r       |
# +-| 0.0|-+
# +-curr:r-+
# |   b   b|
# |b       |
# |        |
# |    b   |
# |        |
# |r   r   |
# | r      |
# |r       |
# +-| 0.0|-+
# +-curr:b-+
# |   b   b|
# |b       |
# |        |
# |    b   |
# |        |
# |r r r   |
# |        |
# |r       |
# +-| 0.0|-+
# +-curr:r-+
# |   b   b|
# |b       |
# |        |
# |        |
# |     b  |
# |r r r   |
# |        |
# |r       |
# +-| 0.0|-+
# +-curr:b-+
# |   b   b|
# |b       |
# |        |
# |      r |
# |        |
# |r r     |
# |        |
# |r       |
# +-| 1.0|-+
# +-curr:r-+
# |   b   b|
# |        |
# | b      |
# |      r |
# |        |
# |r r     |
# |        |
# |r       |
# +-| 1.0|-+
# +-curr:b-+
# |   b   b|
# |        |
# | b      |
# |      r |
# |        |
# |r r     |
# | r      |
# |        |
# +-| 1.0|-+
# +-curr:r-+
# |       b|
# |    b   |
# | b      |
# |      r |
# |        |
# |r r     |
# | r      |
# |        |
# +-| 1.0|-+
# +-curr:b-+
# |       b|
# |    b   |
# | b      |
# |      r |
# |   r    |
# |r       |
# | r      |
# |        |
# +-| 1.0|-+
# +-curr:r-+
# |       b|
# |    b   |
# |        |
# |b     r |
# |   r    |
# |r       |
# | r      |
# |        |
# +-| 1.0|-+
# +-curr:b-+
# |       b|
# |    b   |
# |        |
# |b     r |
# |   r    |
# |r r     |
# |        |
# |        |
# +-| 1.0|-+
# +-curr:r-+
# |       b|
# |    b   |
# |        |
# |      r |
# | b r    |
# |r r     |
# |        |
# |        |
# +-| 1.0|-+
# +-curr:b-+
# |       b|
# |    b   |
# |        |
# |r     r |
# |   r    |
# |r       |
# |        |
# |        |
# +-| 2.0|-+
# +-curr:r-+
# |        |
# |    b b |
# |        |
# |r     r |
# |   r    |
# |r       |
# |        |
# |        |
# +-| 2.0|-+
# +-curr:b-+
# |        |
# |    b b |
# |        |
# |r     r |
# | r r    |
# |        |
# |        |
# |        |
# +-| 2.0|-+
# +-curr:r-+
# |        |
# |    b   |
# |       b|
# |r     r |
# | r r    |
# |        |
# |        |
# |        |
# +-| 2.0|-+
# +-curr:b-+
# |        |
# |    b   |
# |       b|
# |r r   r |
# | r      |
# |        |
# |        |
# |        |
# +-| 2.0|-+
# +-curr:r-+
# |        |
# |    b   |
# |        |
# |r r     |
# | r   b  |
# |        |
# |        |
# |        |
# +-| 1.0|-+
# +-curr:b-+
# |        |
# |    b   |
# | r      |
# |r       |
# | r   b  |
# |        |
# |        |
# |        |
# +-| 1.0|-+
# +-curr:r-+
# |        |
# |    b   |
# | r      |
# |r       |
# | r      |
# |      b |
# |        |
# |        |
# +-| 1.0|-+
# +-curr:b-+
# |        |
# |    b   |
# | r      |
# |r r     |
# |        |
# |      b |
# |        |
# |        |
# +-| 1.0|-+
# +-curr:r-+
# |        |
# |    b   |
# | r      |
# |r r     |
# |        |
# |        |
# |       b|
# |        |
# +-| 1.0|-+
# +-curr:b-+
# |        |
# |  r b   |
# |        |
# |r r     |
# |        |
# |        |
# |       b|
# |        |
# +-| 1.0|-+
# +-curr:r-+
# |        |
# |  r b   |
# |        |
# |r r     |
# |        |
# |        |
# |        |
# |      B |
# +-| 0.5|-+
# +-curr:b-+
# |        |
# |  r b   |
# | r      |
# |r       |
# |        |
# |        |
# |        |
# |      B |
# +-| 0.5|-+
# +-curr:r-+
# |        |
# |  r b   |
# | r      |
# |r       |
# |        |
# |        |
# |       B|
# |        |
# +-| 0.5|-+
# +-curr:b-+
# |        |
# |r r b   |
# |        |
# |r       |
# |        |
# |        |
# |       B|
# |        |
# +-| 0.5|-+
# +-curr:r-+
# |        |
# |r r b   |
# |        |
# |r       |
# |        |
# |        |
# |        |
# |      B |
# +-| 0.5|-+
# +-curr:b-+
# |   R    |
# |r   b   |
# |        |
# |r       |
# |        |
# |        |
# |        |
# |      B |
# +-| 1.0|-+
# +-curr:r-+
# |   R    |
# |r       |
# |     b  |
# |r       |
# |        |
# |        |
# |        |
# |      B |
# +-| 1.0|-+
# +-curr:b-+
# |   R    |
# |r       |
# | r   b  |
# |        |
# |        |
# |        |
# |        |
# |      B |
# +-| 1.0|-+
# +-curr:r-+
# |   R    |
# |r       |
# | r   b  |
# |        |
# |        |
# |        |
# |       B|
# |        |
# +-| 1.0|-+
# +-curr:b-+
# |   R    |
# |r r     |
# |     b  |
# |        |
# |        |
# |        |
# |       B|
# |        |
# +-| 1.0|-+
# +-curr:r-+
# |   R    |
# |r r     |
# |     b  |
# |        |
# |        |
# |        |
# |        |
# |      B |
# +-| 1.0|-+
# +-curr:b-+
# | R R    |
# |r       |
# |     b  |
# |        |
# |        |
# |        |
# |        |
# |      B |
# +-| 1.5|-+
# +-curr:r-+
# | R R    |
# |r       |
# |     b  |
# |        |
# |        |
# |        |
# |       B|
# |        |
# +-| 1.5|-+
# +-curr:b-+
# |   R    |
# |r R     |
# |     b  |
# |        |
# |        |
# |        |
# |       B|
# |        |
# +-| 1.5|-+
# +-curr:r-+
# |   R    |
# |r R     |
# |     b  |
# |        |
# |        |
# |        |
# |        |
# |      B |
# +-| 1.5|-+
# +-curr:b-+
# |   R    |
# |r       |
# |   R b  |
# |        |
# |        |
# |        |
# |        |
# |      B |
# +-| 1.5|-+
# +-curr:r-+
# |   R    |
# |r       |
# |   R b  |
# |        |
# |        |
# |        |
# |       B|
# |        |
# +-| 1.5|-+
# +-curr:b-+
# |   R    |
# |r   R   |
# |     b  |
# |        |
# |        |
# |        |
# |       B|
# |        |
# +-| 1.5|-+
# +-curr:r-+
# |   R    |
# |r   R   |
# |        |
# |      b |
# |        |
# |        |
# |       B|
# |        |
# +-| 1.5|-+
# +-curr:b-+
# |   R R  |
# |r       |
# |        |
# |      b |
# |        |
# |        |
# |       B|
# |        |
# +-| 1.5|-+
# +-curr:r-+
# |   R R  |
# |r       |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 1.5|-+
# +-curr:b-+
# | R R R  |
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R R  |
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# ...
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:r-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:b-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |       B|
# |        |
# +-| 2.0|-+
# +-curr:r-+
# | R R   R|
# |        |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# +-curr:b-+
# | R R    |
# |      R |
# |        |
# |        |
# |       b|
# |        |
# |        |
# |      B |
# +-| 2.0|-+
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       9     break
#      10 print(str(child_node_2.state))
# ---> 11 child_node_1 = bot1.minimax_move(False, child_node_2)
#      13 if not child_node_1:
#      14     break
#
# File ~/Projects/PW/golem/minimax-checkers/src/checkers/minimax.py:24, in MiniMaxGameTree.minimax_move(self, first_move, root_node)
#      21     else:
#      22         raise Exception("No such state in the tree")
# ---> 24 _, best_child = self.root.best_minimax(
#      25     self.root.state.current_player == "r",
#      26     self.tree_depth + self.root.node_depth,
#      27 )
#      29 if not best_child:
#      30     return None
#
# File ~/Projects/PW/golem/minimax-checkers/src/checkers/node.py:56, in GameNode.best_minimax(self, maximizing_player, tree_depth, alpha, beta)
#      54 best_child = None
#      55 for child in self.children:
# ---> 56     score, _ = child.best_minimax(not maximizing_player, tree_depth, alpha, beta)
#      57     if best_score >= score:
#      58         best_score = score
#
# File ~/Projects/PW/golem/minimax-checkers/src/checkers/node.py:44, in GameNode.best_minimax(self, maximizing_player, tree_depth, alpha, beta)
#      42 best_child = None
#      43 for child in self.children:
# ---> 44     score, _ = child.best_minimax(not maximizing_player, tree_depth, alpha, beta)
#      45     if best_score <= score:
#      46         best_score = score
#
# File ~/Projects/PW/golem/minimax-checkers/src/checkers/node.py:56, in GameNode.best_minimax(self, maximizing_player, tree_depth, alpha, beta)
#      54 best_child = None
#      55 for child in self.children:
# ---> 56     score, _ = child.best_minimax(not maximizing_player, tree_depth, alpha, beta)
#      57     if best_score >= score:
#      58         best_score = score
#
# File ~/Projects/PW/golem/minimax-checkers/src/checkers/node.py:44, in GameNode.best_minimax(self, maximizing_player, tree_depth, alpha, beta)
#      42 best_child = None
#      43 for child in self.children:
# ---> 44     score, _ = child.best_minimax(not maximizing_player, tree_depth, alpha, beta)
#      45     if best_score <= score:
#      46         best_score = score
#
# File ~/Projects/PW/golem/minimax-checkers/src/checkers/node.py:35, in GameNode.best_minimax(self, maximizing_player, tree_depth, alpha, beta)
#      32 if self.node_depth > tree_depth or abs(self.state.score) == inf:
#      33     return self.state.score, None  # score and GameNode
# ---> 35 self.init_children()
#      37 if not self.children:
#      38     return self.state.score, None
#
# File ~/Projects/PW/golem/minimax-checkers/src/checkers/node.py:26, in GameNode.init_children(self)
#      22 def init_children(self) -> None:
#      23     if self.children is None:
#      24         self.children = [
#      25             GameNode(state, self.node_depth + 1)
# ---> 26             for state in self.state.next_states()
#      27         ]
#
# File ~/Projects/PW/golem/minimax-checkers/src/checkers/state.py:129, in GameState.next_states(self)
#     122     continue
#     124 if (
#     125     self.board[ny][nx] == " "
#     126     and not has_to_capture
#     127     and (is_super or self.allowed_checker_y_direction() == dy)
#     128 ):
# --> 129     next_possible_states.append(self.with_move(x, y, nx, ny))
#     131 if (
#     132     self.board[ny][nx] != " "
#     133     and self.board[ny][nx].lower() == self.opponent
#     134 ):
#     135     next_captures_states = self.bfs(x, y)
#
# File ~/Projects/PW/golem/minimax-checkers/src/checkers/state.py:155, in GameState.with_move(self, from_x, from_y, to_x, to_y)
#     147 """
#     148 Creates a new game with the specified move.
#     149 If this move does not capture the enemy, the turn ends.
#     150
#     151 :return: new game state after a move has been made
#     152 """
#     153 delta_x, delta_y = to_x - from_x, to_y - from_y
# --> 155 new_state = deepcopy(self)
#     156 if GameState._is_capture(delta_x, delta_y):
#     157     mid_x, mid_y = from_x + delta_x // 2, from_y + delta_y // 2
#
# File ~/.local/share/uv/python/cpython-3.13.8-macos-aarch64-none/lib/python3.13/copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File ~/.local/share/uv/python/cpython-3.13.8-macos-aarch64-none/lib/python3.13/copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File ~/.local/share/uv/python/cpython-3.13.8-macos-aarch64-none/lib/python3.13/copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~/.local/share/uv/python/cpython-3.13.8-macos-aarch64-none/lib/python3.13/copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File ~/.local/share/uv/python/cpython-3.13.8-macos-aarch64-none/lib/python3.13/copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~/.local/share/uv/python/cpython-3.13.8-macos-aarch64-none/lib/python3.13/copy.py:197, in _deepcopy_list(x, memo, deepcopy)
#     195 append = y.append
#     196 for a in x:
# --> 197     append(deepcopy(a, memo))
#     198 return y
#
# File ~/.local/share/uv/python/cpython-3.13.8-macos-aarch64-none/lib/python3.13/copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~/.local/share/uv/python/cpython-3.13.8-macos-aarch64-none/lib/python3.13/copy.py:197, in _deepcopy_list(x, memo, deepcopy)
#     195 append = y.append
#     196 for a in x:
# --> 197     append(deepcopy(a, memo))
#     198 return y
#
# File ~/.local/share/uv/python/cpython-3.13.8-macos-aarch64-none/lib/python3.13/copy.py:119, in deepcopy(x, memo, _nil)
#     115 d[bytearray] = bytearray.copy
#     117 del d, t
# --> 119 def deepcopy(x, memo=None, _nil=[]):
#     120     """Deep copy operation on arbitrary Python objects.
#     121
#     122     See the module's __doc__ string for more info.
#     123     """
#     125     d = id(x)
#
# KeyboardInterrupt:
